# %% [markdown]
# # TSNE

# %% [markdown]
# ## Importing the libraries

# %%
# import the necessary packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")

from sklearn.manifold import TSNE

# %% [markdown]
# ## Loading the Dataset

# %%
# load the dataset TNSE_data.csv
df = pd.read_csv('TSNE_data.csv')
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.shape
# Out:
# (569, 31)

# %% [markdown]
# ## Segregating the target variable from the rest of the dataset

# %%
# seggregate the target variable and the rest of the features
X = df.drop('diagnosis', axis=1)
y = df['diagnosis']

# %% [markdown]
# ## Implementing TSNE

# %%
# create a TSNE object with 2 components and transform the data
tsne = TSNE(n_components=2, random_state=0)
X_2d = tsne.fit_transform(X)
# Out:
# /Users/balajisundararaman/miniforge3/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/balajisundararaman/miniforge3/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# ## Transformed Reduced Dimension Data

# %%
X_2d
# Out:
# array([[  7.784421 , -29.91619  ],
#        [ 10.20023  , -31.30578  ],
#        [ 12.025103 , -26.973227 ],
#        ...,
#        [ 20.22669  , -10.1556015],
#        [ 11.045506 , -29.266119 ],
#        [-30.770226 , -18.300062 ]], dtype=float32)

# %%
X_2d.shape
# Out:
# (569, 2)

# %%
# create a dataframe with the 2 components and add the target variable
df_2d = pd.DataFrame(X_2d, columns=['t1', 't2'])
df_2d['diagnosis'] = y
df_2d.head()
# Out:
#           t1         t2 diagnosis
# 0   7.784421 -29.916189         M
# 1  10.200230 -31.305780         M
# 2  12.025103 -26.973227         M
# 3 -17.745667  15.138823         M
# 4  14.445130 -26.531887         M

# %% [markdown]
# ## Visualizing the results of TSNE in terms of the target variable classes

# %%
import seaborn as sns
sns.scatterplot(x='t1', y='t2', hue='diagnosis', data=df_2d);
