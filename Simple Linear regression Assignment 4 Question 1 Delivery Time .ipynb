# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf

# %%
# import dataset
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\Simple Linear regression\delivery_time (2).csv')
dataset
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
sns.distplot(dataset['Delivery Time'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Delivery Time', ylabel='Density'>

# %%
sns.distplot(dataset['Sorting Time'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sorting Time', ylabel='Density'>

# %%
# Renaming Columns
dataset=dataset.rename({'Delivery Time':'delivery_time', 'Sorting Time':'sorting_time'},axis=1)
dataset
# Out:
#     delivery_time  sorting_time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
dataset.corr()
# Out:
#                delivery_time  sorting_time
# delivery_time       1.000000      0.825997
# sorting_time        0.825997      1.000000

# %%
dataset.mean()
# Out:
# delivery_time    16.790952
# sorting_time      6.190476
# dtype: float64

# %%
dataset.median()
# Out:
# delivery_time    17.83
# sorting_time      6.00
# dtype: float64

# %%
dataset.kurt()
# Out:
# delivery_time    0.317960
# sorting_time    -1.148455
# dtype: float64

# %%
dataset.skew()
# Out:
# delivery_time    0.352390
# sorting_time     0.047115
# dtype: float64

# %%
dataset.describe()
# Out:
#        delivery_time  sorting_time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
sns.regplot(x=dataset['sorting_time'],y=dataset['delivery_time'])
# Out:
# <AxesSubplot:xlabel='sorting_time', ylabel='delivery_time'>

# %%
model=smf.ols("delivery_time~sorting_time",data=dataset).fit()

# %%
# Finding Coefficient parameters
model.params
# Out:
# Intercept       6.582734
# sorting_time    1.649020
# dtype: float64

# %%
# Finding tvalues and pvalues
model.tvalues , model.pvalues
# Out:
# (Intercept       3.823349
#  sorting_time    6.387447
#  dtype: float64,
#  Intercept       0.001147
#  sorting_time    0.000004
#  dtype: float64)

# %%
# Finding Rsquared Values
model.rsquared , model.rsquared_adj
# Out:
# (0.6822714748417231, 0.6655489208860244)

# %%
# Manual prediction for say sorting time 5
delivery_time = (6.582734) + (1.649020)*(5)
delivery_time
# Out:
# 14.827834

# %%
# Automatic Prediction for say sorting time 5, 8
new_data=pd.Series([5,8])
new_data
# Out:
# 0    5
# 1    8
# dtype: int64

# %%
data_pred=pd.DataFrame(new_data,columns=['sorting_time'])
data_pred
# Out:
#    sorting_time
# 0             5
# 1             8

# %%
model.predict(data_pred)
# Out:
# 0    14.827833
# 1    19.774893
# dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
# Out:
#    Delivery Time  Sorting Time
# 0            NaN            10
# 1            NaN             4
# 2            NaN             6
# 3            NaN             9
# 4            NaN            10

# %%
# Calculate logarithm to base 2 
# on 'Sorting Time' column
import numpy as np
import pandas as pd
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\2Simple Linear regression\delivery_time (2).csv')
dataset['logarithm_base2'] = np.log2(dataset['Sorting Time'])
  
# Show the dataframe
dataset
# Out:
#     Delivery Time  Sorting Time  logarithm_base2
# 0           21.00            10         3.321928
# 1           13.50             4         2.000000
# 2           19.75             6         2.584963
# 3           24.00             9         3.169925
# 4           29.00            10         3.321928
# 5           15.35             6         2.584963
# 6           19.00             7         2.807355
# 7            9.50             3         1.584963
# 8           17.90            10         3.321928
# 9           18.75             9         3.169925
# 10          19.83             8         3.000000
# 11          10.75             4         2.000000
# 12          16.68             7         2.807355
# 13          11.50             3         1.584963
# 14          12.03             3         1.584963
# 15          14.88             4         2.000000
# 16          13.75             6         2.584963
# 17          18.11             7         2.807355
# ...

# %%
# Calculate logarithm to 
# base 10 on 'Sorting Time' column
import numpy as np
import pandas as pd
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\2Simple Linear regression\delivery_time (2).csv')
dataset['logarithm_base10'] = np.log10(dataset['Sorting Time'])
  
# Show the dataframe
dataset
# Out:
#     Delivery Time  Sorting Time  logarithm_base10
# 0           21.00            10          1.000000
# 1           13.50             4          0.602060
# 2           19.75             6          0.778151
# 3           24.00             9          0.954243
# 4           29.00            10          1.000000
# 5           15.35             6          0.778151
# 6           19.00             7          0.845098
# 7            9.50             3          0.477121
# 8           17.90            10          1.000000
# 9           18.75             9          0.954243
# 10          19.83             8          0.903090
# 11          10.75             4          0.602060
# 12          16.68             7          0.845098
# 13          11.50             3          0.477121
# 14          12.03             3          0.477121
# 15          14.88             4          0.602060
# 16          13.75             6          0.778151
# 17          18.11             7          0.845098
# ...

# %%
# Calculate natural logarithm on
# 'Sorting Time' column
import numpy as np
import pandas as pd
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\2Simple Linear regression\delivery_time (2).csv')
dataset['natural_log'] = np.log(dataset['Sorting Time'])
  
# Show the dataframe
dataset
# Out:
#     Delivery Time  Sorting Time  natural_log
# 0           21.00            10     2.302585
# 1           13.50             4     1.386294
# 2           19.75             6     1.791759
# 3           24.00             9     2.197225
# 4           29.00            10     2.302585
# 5           15.35             6     1.791759
# 6           19.00             7     1.945910
# 7            9.50             3     1.098612
# 8           17.90            10     2.302585
# 9           18.75             9     2.197225
# 10          19.83             8     2.079442
# 11          10.75             4     1.386294
# 12          16.68             7     1.945910
# 13          11.50             3     1.098612
# 14          12.03             3     1.098612
# 15          14.88             4     1.386294
# 16          13.75             6     1.791759
# 17          18.11             7     1.945910
# 18           8.00             2     0.693147
# 19          17.83             7     1.945910
# ...

# %%
# Calculate logarithm to base 2 
# on 'Delivery Time' column
import numpy as np
import pandas as pd
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\2Simple Linear regression\delivery_time (2).csv')
dataset['logarithm_base2'] = np.log2(dataset['Delivery Time'])
  
# Show the dataframe
dataset
# Out:
#     Delivery Time  Sorting Time  logarithm_base2
# 0           21.00            10         4.392317
# 1           13.50             4         3.754888
# 2           19.75             6         4.303781
# 3           24.00             9         4.584963
# 4           29.00            10         4.857981
# 5           15.35             6         3.940167
# 6           19.00             7         4.247928
# 7            9.50             3         3.247928
# 8           17.90            10         4.161888
# 9           18.75             9         4.228819
# 10          19.83             8         4.309613
# 11          10.75             4         3.426265
# 12          16.68             7         4.060047
# 13          11.50             3         3.523562
# 14          12.03             3         3.588565
# 15          14.88             4         3.895303
# 16          13.75             6         3.781360
# 17          18.11             7         4.178715
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  0 non-null      float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
# Calculate logarithm to 
# base 10 on 'Delivery Time' column
import numpy as np
import pandas as pd
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\2Simple Linear regression\delivery_time (2).csv')
dataset['logarithm_base10'] = np.log10(dataset['Delivery Time'])
  
# Show the dataframe
dataset
# Out:
#     Delivery Time  Sorting Time  logarithm_base10
# 0           21.00            10          1.322219
# 1           13.50             4          1.130334
# 2           19.75             6          1.295567
# 3           24.00             9          1.380211
# 4           29.00            10          1.462398
# 5           15.35             6          1.186108
# 6           19.00             7          1.278754
# 7            9.50             3          0.977724
# 8           17.90            10          1.252853
# 9           18.75             9          1.273001
# 10          19.83             8          1.297323
# 11          10.75             4          1.031408
# 12          16.68             7          1.222196
# 13          11.50             3          1.060698
# 14          12.03             3          1.080266
# 15          14.88             4          1.172603
# 16          13.75             6          1.138303
# 17          18.11             7          1.257918
# ...

# %%
# Calculate natural logarithm on
# 'Delivery Time' column
import numpy as np
import pandas as pd
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\2Simple Linear regression\delivery_time (2).csv')
dataset['natural_log'] = np.log(dataset['Delivery Time'])
  
# Show the dataframe
dataset
# Out:
#     Delivery Time  Sorting Time  natural_log
# 0           21.00            10     3.044522
# 1           13.50             4     2.602690
# 2           19.75             6     2.983153
# 3           24.00             9     3.178054
# 4           29.00            10     3.367296
# 5           15.35             6     2.731115
# 6           19.00             7     2.944439
# 7            9.50             3     2.251292
# 8           17.90            10     2.884801
# 9           18.75             9     2.931194
# 10          19.83             8     2.987196
# 11          10.75             4     2.374906
# 12          16.68             7     2.814210
# 13          11.50             3     2.442347
# 14          12.03             3     2.487404
# 15          14.88             4     2.700018
# 16          13.75             6     2.621039
# 17          18.11             7     2.896464
# 18           8.00             2     2.079442
# 19          17.83             7     2.880882
# ...

# %%
import numpy as np
ar=np.sqrt([21,13.50,19.75,24,29,15.35,19,9.50,17.90,18.75,19.83,10.75,16.68,11.50,12.03,14.88,13.75,18.11,8.00,17.83,21.50])
ar
# Out:
# array([4.58257569, 3.67423461, 4.44409721, 4.89897949, 5.38516481,
#        3.9179076 , 4.35889894, 3.082207  , 4.23083916, 4.33012702,
#        4.45308882, 3.27871926, 4.08411557, 3.39116499, 3.46842904,
#        3.8574603 , 3.70809924, 4.25558457, 2.82842712, 4.22255847,
#        4.63680925])

# %%
import numpy as np
ar=np.square([21,13.50,19.75,24,29,15.35,19,9.50,17.90,18.75,19.83,10.75,16.68,11.50,12.03,14.88,13.75,18.11,8.00,17.83,21.50])
ar
# Out:
# array([441.    , 182.25  , 390.0625, 576.    , 841.    , 235.6225,
#        361.    ,  90.25  , 320.41  , 351.5625, 393.2289, 115.5625,
#        278.2224, 132.25  , 144.7209, 221.4144, 189.0625, 327.9721,
#         64.    , 317.9089, 462.25  ])

# %%
import numpy as np
ar=np.sqrt([10,4,6,9,10,6,7,3,10,9,8,4,7,3,3,4,6,7,2,7,5])
ar
# Out:
# array([3.16227766, 2.        , 2.44948974, 3.        , 3.16227766,
#        2.44948974, 2.64575131, 1.73205081, 3.16227766, 3.        ,
#        2.82842712, 2.        , 2.64575131, 1.73205081, 1.73205081,
#        2.        , 2.44948974, 2.64575131, 1.41421356, 2.64575131,
#        2.23606798])

# %%
import numpy as np
ar=np.square([10,4,6,9,10,6,7,3,10,9,8,4,7,3,3,4,6,7,2,7,5])
ar
# Out:
# array([100,  16,  36,  81, 100,  36,  49,   9, 100,  81,  64,  16,  49,
#          9,   9,  16,  36,  49,   4,  49,  25], dtype=int32)
