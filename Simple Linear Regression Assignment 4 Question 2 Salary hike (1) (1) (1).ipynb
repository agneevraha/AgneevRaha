# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf

# %%
# import dataset
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\Simple Linear regression\Salary_Data (2).csv')
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
sns.distplot(dataset['Salary'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Salary', ylabel='Density'>

# %%
sns.distplot(dataset['YearsExperience'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearsExperience', ylabel='Density'>

# %%
# Renaming Columns
dataset=dataset.rename({'Salary':'salary', 'YearsExperience':'yrsExperience'},axis=1)
dataset
# Out:
#     yrsExperience    salary
# 0             1.1   39343.0
# 1             1.3   46205.0
# 2             1.5   37731.0
# 3             2.0   43525.0
# 4             2.2   39891.0
# 5             2.9   56642.0
# 6             3.0   60150.0
# 7             3.2   54445.0
# 8             3.2   64445.0
# 9             3.7   57189.0
# 10            3.9   63218.0
# 11            4.0   55794.0
# 12            4.0   56957.0
# 13            4.1   57081.0
# 14            4.5   61111.0
# 15            4.9   67938.0
# 16            5.1   66029.0
# 17            5.3   83088.0
# 18            5.9   81363.0
# 19            6.0   93940.0
# 20            6.8   91738.0
# 21            7.1   98273.0
# 22            7.9  101302.0
# 23            8.2  113812.0
# 24            8.7  109431.0
# 25            9.0  105582.0
# 26            9.5  116969.0
# 27            9.6  112635.0
# 28           10.3  122391.0
# 29           10.5  121872.0

# %%
import numpy as np
import matplotlib.pyplot as plt

#make this example reproducible
np.random.seed(0)

#create beta distributed random variable with 200 values
data = np.random.beta(a=4, b=15, size=300)

#create log-transformed data
data_log = np.log(data)

#define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

#create histograms
axs[0].hist(data, edgecolor='black')
axs[1].hist(data_log, edgecolor='black')

#add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Log-Transformed Data')
# Out:
# Text(0.5, 1.0, 'Log-Transformed Data')

# %%
import numpy as np
import matplotlib.pyplot as plt

#make this example reproducible
np.random.seed(0)

#create beta distributed random variable with 200 values
data = np.random.beta(a=1, b=5, size=300)

#create log-transformed data
data_log = np.sqrt(data)

#define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

#create histograms
axs[0].hist(data, edgecolor='black')
axs[1].hist(data_log, edgecolor='black')

#add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Square Root Transformed Data')
# Out:
# Text(0.5, 1.0, 'Square Root Transformed Data')

# %%
import numpy as np
import matplotlib.pyplot as plt

#make this example reproducible
np.random.seed(0)

#create beta distributed random variable with 200 values
data = np.random.beta(a=1, b=5, size=300)

#create log-transformed data
data_log = np.cbrt(data)

#define grid of plots
fig, axs = plt.subplots(nrows=1, ncols=2)

#create histograms
axs[0].hist(data, edgecolor='black')
axs[1].hist(data_log, edgecolor='black')

#add title to each histogram
axs[0].set_title('Original Data')
axs[1].set_title('Cube Root Transformed Data')
# Out:
# Text(0.5, 1.0, 'Cube Root Transformed Data')

# %%
#Cube root squared data is the best modal

# %%
sns.regplot(x=dataset['salary'],y=dataset['yrsExperience'])
# Out:
# <AxesSubplot:xlabel='salary', ylabel='yrsExperience'>

# %%
model=smf.ols("yrsExperience~salary",data=dataset).fit()

# %%
# Finding Coefficient parameters
model.params
# Out:
# Intercept   -2.383161
# salary       0.000101
# dtype: float64

# %%
# Finding tvalues and pvalues
model.tvalues , model.pvalues
# Out:
# (Intercept    -7.281283
#  salary       24.950094
#  dtype: float64,
#  Intercept    6.300123e-08
#  salary       1.143068e-20
#  dtype: float64)

# %%
# Finding Rsquared Values
model.rsquared , model.rsquared_adj
# Out:
# (0.9569566641435086, 0.9554194021486339)

# %%
# Manual prediction for say YearsExperience 5
salary = (-2.38161) + (0.000101)*(5)
salary
# Out:
# -2.381105

# %%
# Automatic Prediction for say YearsExperience 5, 8
new_data=pd.Series([5,8])
new_data
# Out:
# 0    5
# 1    8
# dtype: int64

# %%
data_pred=pd.DataFrame(new_data,columns=['salary'])
data_pred
# Out:
#    salary
# 0       5
# 1       8

# %%
model.predict(data_pred)
# Out:
# 0   -2.382654
# 1   -2.382350
# dtype: float64

# %%
# Calculate logarithm to base 2 
# on 'Salary' column
import numpy as np
import pandas as pd
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\2Simple Linear regression\Salary_Data (2).csv')
dataset['logarithm_base2'] = np.log2(dataset['Salary'])
  
# Show the dataframe
dataset
# Out:
#     YearsExperience    Salary  logarithm_base2
# 0               1.1   39343.0        15.263819
# 1               1.3   46205.0        15.495761
# 2               1.5   37731.0        15.203463
# 3               2.0   43525.0        15.409557
# 4               2.2   39891.0        15.283776
# 5               2.9   56642.0        15.789585
# 6               3.0   60150.0        15.876277
# 7               3.2   54445.0        15.732512
# 8               3.2   64445.0        15.975781
# 9               3.7   57189.0        15.803450
# 10              3.9   63218.0        15.948048
# 11              4.0   55794.0        15.767822
# 12              4.0   56957.0        15.797586
# 13              4.1   57081.0        15.800723
# 14              4.5   61111.0        15.899144
# 15              4.9   67938.0        16.051931
# 16              5.1   66029.0        16.010812
# 17              5.3   83088.0        16.342353
# 18              5.9   81363.0        16.312085
# ...

# %%
# Calculate logarithm to 
# base 10 on 'Salary' column
import numpy as np
import pandas as pd
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\2Simple Linear regression\Salary_Data (2).csv')
dataset['logarithm_base10'] = np.log10(dataset['Salary'])
  
# Show the dataframe
dataset
# Out:
#     YearsExperience    Salary  logarithm_base10
# 0               1.1   39343.0          4.594867
# 1               1.3   46205.0          4.664689
# 2               1.5   37731.0          4.576698
# 3               2.0   43525.0          4.638739
# 4               2.2   39891.0          4.600875
# 5               2.9   56642.0          4.753139
# 6               3.0   60150.0          4.779236
# 7               3.2   54445.0          4.735958
# 8               3.2   64445.0          4.809189
# 9               3.7   57189.0          4.757313
# 10              3.9   63218.0          4.800841
# 11              4.0   55794.0          4.746587
# 12              4.0   56957.0          4.755547
# 13              4.1   57081.0          4.756492
# 14              4.5   61111.0          4.786119
# 15              4.9   67938.0          4.832113
# 16              5.1   66029.0          4.819735
# 17              5.3   83088.0          4.919538
# 18              5.9   81363.0          4.910427
# ...

# %%
# Calculate natural logarithm on
# 'Salary' column
import numpy as np
import pandas as pd
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\2Simple Linear regression\Salary_Data (2).csv')
dataset['natural_log'] = np.log(dataset['Salary'])
  
# Show the dataframe
dataset
# Out:
#     YearsExperience    Salary  natural_log
# 0               1.1   39343.0    10.580073
# 1               1.3   46205.0    10.740843
# 2               1.5   37731.0    10.538237
# 3               2.0   43525.0    10.681091
# 4               2.2   39891.0    10.593906
# 5               2.9   56642.0    10.944506
# 6               3.0   60150.0    11.004597
# 7               3.2   54445.0    10.904946
# 8               3.2   64445.0    11.073567
# 9               3.7   57189.0    10.954117
# 10              3.9   63218.0    11.054344
# 11              4.0   55794.0    10.929422
# 12              4.0   56957.0    10.950052
# 13              4.1   57081.0    10.952227
# 14              4.5   61111.0    11.020447
# 15              4.9   67938.0    11.126351
# 16              5.1   66029.0    11.097849
# 17              5.3   83088.0    11.327656
# 18              5.9   81363.0    11.306676
# 19              6.0   93940.0    11.450412
# 20              6.8   91738.0    11.426692
# ...

# %%
# Calculate logarithm to 
# sqrt on 'Salary' column
import numpy as np
import pandas as pd
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\2Simple Linear regression\Salary_Data (2).csv')
dataset['sqrt'] = np.sqrt(dataset['Salary'])
data=np.sqrt(dataset['Salary']) 
# Show the dataframe
dataset
# Out:
#     YearsExperience    Salary        sqrt
# 0               1.1   39343.0  198.350700
# 1               1.3   46205.0  214.953483
# 2               1.5   37731.0  194.244691
# 3               2.0   43525.0  208.626460
# 4               2.2   39891.0  199.727314
# 5               2.9   56642.0  237.995798
# 6               3.0   60150.0  245.254969
# 7               3.2   54445.0  233.334524
# 8               3.2   64445.0  253.860198
# 9               3.7   57189.0  239.142217
# 10              3.9   63218.0  251.431899
# 11              4.0   55794.0  236.207536
# 12              4.0   56957.0  238.656657
# 13              4.1   57081.0  238.916303
# 14              4.5   61111.0  247.206392
# 15              4.9   67938.0  260.649190
# 16              5.1   66029.0  256.961087
# 17              5.3   83088.0  288.249892
# 18              5.9   81363.0  285.242003
# 19              6.0   93940.0  306.496330
# 20              6.8   91738.0  302.882816
# ...

# %%
#Predicted Value
import seaborn as sns
e=sns.distplot(dataset['sqrt'], hist=False, rug=True)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
#Actual Value
s=sns.distplot(dataset['Salary'],bins=8,hist=False,rug=True)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns
sns.jointplot(dataset['Salary'],dataset['sqrt'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn import metrics

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22644\877455251.py in <module>
# ----> 1 mean_sq_err=metrics.mean_squared_error(e,s)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      98         correct keyword.
#      99     """
# --> 100     check_consistent_length(y_true, y_pred)
#     101     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ...

# %%
# Calculate logarithm to 
# base 10 on 'Salary' column
import numpy as np
import pandas as pd
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\2Simple Linear regression\Salary_Data (2).csv')
dataset['cubert'] = np.cbrt(dataset['Salary'])
  
# Show the dataframe
dataset
# Out:
#     YearsExperience    Salary     cubert
# 0               1.1   39343.0  34.011242
# 1               1.3   46205.0  35.883626
# 2               1.5   37731.0  33.540235
# 3               2.0   43525.0  35.175984
# 4               2.2   39891.0  34.168426
# 5               2.9   56642.0  38.404271
# 6               3.0   60150.0  39.181273
# 7               3.2   54445.0  37.901174
# 8               3.2   64445.0  40.092494
# 9               3.7   57189.0  38.527500
# 10              3.9   63218.0  39.836415
# 11              4.0   55794.0  38.211654
# 12              4.0   56957.0  38.475331
# 13              4.1   57081.0  38.503232
# 14              4.5   61111.0  39.388834
# 15              4.9   67938.0  40.804142
# 16              5.1   66029.0  40.418318
# 17              5.3   83088.0  43.636117
# 18              5.9   81363.0  43.332025
# 19              6.0   93940.0  45.458683
# 20              6.8   91738.0  45.100680
# 21              7.1   98273.0  46.147134
# ...

# %%
import seaborn as sns
sns.distplot(dataset['Salary'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Salary', ylabel='Density'>

# %%
from pandas import read_csv
from matplotlib import pyplot

# %%
dataset=pd.read_csv(r'C:\Users\hp\Desktop\ExcelR\Assignments Folder\Simple Linear regression\Salary_Data (2).csv',header=0, index_col=0, parse_dates=True)

# %%
# line plot
pyplot.subplot(211)
pyplot.plot(dataset)
# histogram
pyplot.subplot(212)
pyplot.hist(dataset)
pyplot.show()
