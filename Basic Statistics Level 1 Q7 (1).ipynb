# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\hp\Desktop\ExcelR\Assignments Folder\1Basic Statistics Level_1\Q7 (1).csv")

# %%
data
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
data.mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6912\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6912\4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
data.mode()
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0           AMC Javelin    3.07   3.44  17.02
# 1    Cadillac Fleetwood    3.92    NaN  18.90
# 2            Camaro Z28     NaN    NaN    NaN
# 3     Chrysler Imperial     NaN    NaN    NaN
# 4            Datsun 710     NaN    NaN    NaN
# 5      Dodge Challenger     NaN    NaN    NaN
# 6            Duster 360     NaN    NaN    NaN
# 7          Ferrari Dino     NaN    NaN    NaN
# 8              Fiat 128     NaN    NaN    NaN
# 9             Fiat X1-9     NaN    NaN    NaN
# 10       Ford Pantera L     NaN    NaN    NaN
# 11          Honda Civic     NaN    NaN    NaN
# 12       Hornet 4 Drive     NaN    NaN    NaN
# 13    Hornet Sportabout     NaN    NaN    NaN
# 14  Lincoln Continental     NaN    NaN    NaN
# 15         Lotus Europa     NaN    NaN    NaN
# 16        Maserati Bora     NaN    NaN    NaN
# 17            Mazda RX4     NaN    NaN    NaN
# 18        Mazda RX4 Wag     NaN    NaN    NaN
# ...

# %%
data.var()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6912\445316826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.var()
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %%
data.std()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6912\2723740006.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.std()
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %%
data
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
data.max()
# Out:
# Unnamed: 0    Volvo 142E
# Points              4.93
# Score              5.424
# Weigh               22.9
# dtype: object

# %%
#for finding range, Points Range=2.17  Score Range= 3.911   Weight Range=8.4

# %%
data.min()
# Out:
# Unnamed: 0    AMC Javelin
# Points               2.76
# Score               1.513
# Weigh                14.5
# dtype: object

# %%
data.corr()
# Out:
#           Points     Score     Weigh
# Points  1.000000 -0.712441  0.091205
# Score  -0.712441  1.000000 -0.174716
# Weigh   0.091205 -0.174716  1.000000
